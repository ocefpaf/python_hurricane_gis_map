# %% [markdown]
# # Exploring the NHC Advisories and Sea Surface Height during Hurricane Irma
#
#
# This notebook aims to demonstrate how to create a simple interactive GIS map with the National Hurricane Center predictions [1] and the observed sea surface height from CO-OPS [2].
#
#
# See https://tidesandcurrents.noaa.gov/quicklook/view.html?name=IRMA for the latest information on Irma.
#
# 1. http://www.nhc.noaa.gov/gis/
# 2. https://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/

# %% [markdown]
# First we set a date around the 2017-09-07 to search for the observations.

# %%
from datetime import datetime, timedelta

event_date = datetime(2017, 9, 7)

start_time = event_date - timedelta(days=3)
end_time = event_date + timedelta(days=4)

# %% [markdown]
# As we did before now we need o set all the parameters for the filter: the units for the observations, the bounding box, and the SOS name for the variable of interest. So we can use `pyoos` to assemble a collector to download the data and download into a pandas `DataFrame`.

# %%
import cf_units
from ioos_tools.ioos import collector2table
import pandas as pd
from pyoos.collectors.coops.coops_sos import CoopsSos


def get_coops_ssh(sos_name='water_surface_height_above_reference_datum',
                 units=cf_units.Unit('meters'),
                 bbox=[-86, 12.5, -57, 30.5],
                 verbose=False):
    collector = CoopsSos()
    collector.set_bbox(bbox)
    collector.end_time = end_time
    collector.start_time = start_time
    collector.variables = [sos_name]
    ofrs = collector.server.offerings
    title = collector.server.identification.title
    config = dict(
        units=units,
        sos_name=sos_name,
    )

    data = collector2table(
        collector=collector,
        config=config,
        col='{} ({})'.format(sos_name, units.format(cf_units.UT_ISO_8859_1))
    )

    # Clean the table.
    table = dict(
        station_name=[s._metadata.get('station_name') for s in data],
        station_code=[s._metadata.get('station_code') for s in data],
        sensor=[s._metadata.get('sensor') for s in data],
        lon=[s._metadata.get('lon') for s in data],
        lat=[s._metadata.get('lat') for s in data],
        depth=[s._metadata.get('depth', 'NA') for s in data],
    )

    table = pd.DataFrame(table).set_index('station_name')
    if verbose:
        print('Collector offerings')
        print('{}: {} offerings'.format(title, len(ofrs)))
    return data, table

# %%
bbox = [-86, 12.5, -57, 30.5]

ssh, ssh_table = get_coops_ssh(
    sos_name='water_surface_height_above_reference_datum',
    units=cf_units.Unit('meters'),
    bbox=bbox,
)

ssh_table
# Out:
#                                         depth      lat      lon  \
# station_name
# Mayport (Bar Pilots Dock), FL            None  30.3982 -81.4279
# Dames Point, FL                          None  30.3872 -81.5592
# Southbank Riverwalk, St Johns River, FL  None  30.3205 -81.6591
# I-295 Bridge, St Johns River, FL         None  30.1924 -81.6900
# Racy Point, St Johns River, FL           None  29.8002 -81.5498
# Trident Pier, Port Canaveral, FL         None  28.4158 -80.5931
# Lake Worth Pier, Atlantic Ocean, FL      None  26.6128 -80.0342
# Virginia Key, Biscayne Bay, FL           None  25.7317 -80.1617
# Vaca Key, Florida Bay, FL                None  24.7110 -81.1065
# Key West, FL                             None  24.5557 -81.8079
# Naples, Gulf of Mexico, FL               None  26.1317 -81.8075
# Fort Myers, Caloosahatchee River, FL     None  26.6480 -81.8710
# Port Manatee, FL                         None  27.6383 -82.5625
# St Petersburg, Tampa Bay, FL             None  27.7606 -82.6269
# Old Port Tampa, FL                       None  27.8578 -82.5528
# Mckay Bay Entrance, FL                   None  27.9130 -82.4250
# Clearwater Beach, FL                     None  27.9783 -82.8317
# Cedar Key, FL                            None  29.1336 -83.0309
# Apalachicola, FL                         None  29.7244 -84.9806
# Panama City, FL                          None  30.1523 -85.7000
# Panama City Beach, FL                    None  30.2133 -85.8783
# Christiansted Harbor, St Croix, VI       None  17.7477 -64.6984
# Lameshur Bay, St John, VI                None  18.3182 -64.7242
# Lime Tree Bay. St. Croix, VI             None  17.6947 -64.7538
# Culebra, PR                              None  18.3009 -65.3025
# Isabel Segunda, Vieques Island, PR       None  18.1525 -65.4438
# Fajardo, PR                              None  18.3352 -65.6310
# Yabucoa Harbor, PR                       None  18.0551 -65.8330
# San Juan, La Puntilla, San Juan Bay, PR  None  18.4592 -66.1164
# Arecibo, PR                              None  18.4806 -66.7025
# Magueyes Island, PR                      None  17.9700 -67.0464
# Mayaguez, PR                             None  18.2176 -67.1588
# Mona Island, PR                          None  18.0899 -67.9385
# Barbuda, Antigua and Barbuda             None  17.5908 -61.8206
#
#                                                                              sensor  \
# station_name
# Mayport (Bar Pilots Dock), FL            urn:ioos:sensor:NOAA.NOS.CO-OPS:8720218:A1
# Dames Point, FL                          urn:ioos:sensor:NOAA.NOS.CO-OPS:8720219:A1
# Southbank Riverwalk, St Johns River, FL  urn:ioos:sensor:NOAA.NOS.CO-OPS:8720226:Y1
# I-295 Bridge, St Johns River, FL         urn:ioos:sensor:NOAA.NOS.CO-OPS:8720357:A1
# Racy Point, St Johns River, FL           urn:ioos:sensor:NOAA.NOS.CO-OPS:8720625:A1
# Trident Pier, Port Canaveral, FL         urn:ioos:sensor:NOAA.NOS.CO-OPS:8721604:A1
# Lake Worth Pier, Atlantic Ocean, FL      urn:ioos:sensor:NOAA.NOS.CO-OPS:8722670:N1
# Virginia Key, Biscayne Bay, FL           urn:ioos:sensor:NOAA.NOS.CO-OPS:8723214:A1
# Vaca Key, Florida Bay, FL                urn:ioos:sensor:NOAA.NOS.CO-OPS:8723970:A1
# Key West, FL                             urn:ioos:sensor:NOAA.NOS.CO-OPS:8724580:A1
# Naples, Gulf of Mexico, FL               urn:ioos:sensor:NOAA.NOS.CO-OPS:8725110:A1
# Fort Myers, Caloosahatchee River, FL     urn:ioos:sensor:NOAA.NOS.CO-OPS:8725520:A1
# Port Manatee, FL                         urn:ioos:sensor:NOAA.NOS.CO-OPS:8726384:A1
# St Petersburg, Tampa Bay, FL             urn:ioos:sensor:NOAA.NOS.CO-OPS:8726520:Y1
# Old Port Tampa, FL                       urn:ioos:sensor:NOAA.NOS.CO-OPS:8726607:B1
# Mckay Bay Entrance, FL                   urn:ioos:sensor:NOAA.NOS.CO-OPS:8726667:A1
# Clearwater Beach, FL                     urn:ioos:sensor:NOAA.NOS.CO-OPS:8726724:A1
# Cedar Key, FL                            urn:ioos:sensor:NOAA.NOS.CO-OPS:8727520:A1
# Apalachicola, FL                         urn:ioos:sensor:NOAA.NOS.CO-OPS:8728690:A1
# Panama City, FL                          urn:ioos:sensor:NOAA.NOS.CO-OPS:8729108:A1
# Panama City Beach, FL                    urn:ioos:sensor:NOAA.NOS.CO-OPS:8729210:A1
# Christiansted Harbor, St Croix, VI       urn:ioos:sensor:NOAA.NOS.CO-OPS:9751364:A1
# Lameshur Bay, St John, VI                urn:ioos:sensor:NOAA.NOS.CO-OPS:9751381:A1
# Lime Tree Bay. St. Croix, VI             urn:ioos:sensor:NOAA.NOS.CO-OPS:9751401:Y1
# Culebra, PR                              urn:ioos:sensor:NOAA.NOS.CO-OPS:9752235:N1
# Isabel Segunda, Vieques Island, PR       urn:ioos:sensor:NOAA.NOS.CO-OPS:9752619:A1
# Fajardo, PR                              urn:ioos:sensor:NOAA.NOS.CO-OPS:9753216:A1
# Yabucoa Harbor, PR                       urn:ioos:sensor:NOAA.NOS.CO-OPS:9754228:A1
# San Juan, La Puntilla, San Juan Bay, PR  urn:ioos:sensor:NOAA.NOS.CO-OPS:9755371:Y1
# Arecibo, PR                              urn:ioos:sensor:NOAA.NOS.CO-OPS:9757809:B1
# Magueyes Island, PR                      urn:ioos:sensor:NOAA.NOS.CO-OPS:9759110:A1
# Mayaguez, PR                             urn:ioos:sensor:NOAA.NOS.CO-OPS:9759394:Y1
# Mona Island, PR                          urn:ioos:sensor:NOAA.NOS.CO-OPS:9759938:T1
# Barbuda, Antigua and Barbuda             urn:ioos:sensor:NOAA.NOS.CO-OPS:9761115:N1
#
#                                         station_code
# station_name
# Mayport (Bar Pilots Dock), FL                8720218
# Dames Point, FL                              8720219
# Southbank Riverwalk, St Johns River, FL      8720226
# I-295 Bridge, St Johns River, FL             8720357
# Racy Point, St Johns River, FL               8720625
# Trident Pier, Port Canaveral, FL             8721604
# Lake Worth Pier, Atlantic Ocean, FL          8722670
# Virginia Key, Biscayne Bay, FL               8723214
# Vaca Key, Florida Bay, FL                    8723970
# Key West, FL                                 8724580
# Naples, Gulf of Mexico, FL                   8725110
# Fort Myers, Caloosahatchee River, FL         8725520
# Port Manatee, FL                             8726384
# St Petersburg, Tampa Bay, FL                 8726520
# Old Port Tampa, FL                           8726607
# Mckay Bay Entrance, FL                       8726667
# Clearwater Beach, FL                         8726724
# Cedar Key, FL                                8727520
# Apalachicola, FL                             8728690
# Panama City, FL                              8729108
# Panama City Beach, FL                        8729210
# Christiansted Harbor, St Croix, VI           9751364
# Lameshur Bay, St John, VI                    9751381
# Lime Tree Bay. St. Croix, VI                 9751401
# Culebra, PR                                  9752235
# Isabel Segunda, Vieques Island, PR           9752619
# Fajardo, PR                                  9753216
# Yabucoa Harbor, PR                           9754228
# San Juan, La Puntilla, San Juan Bay, PR      9755371
# Arecibo, PR                                  9757809
# Magueyes Island, PR                          9759110
# Mayaguez, PR                                 9759394
# Mona Island, PR                              9759938
# Barbuda, Antigua and Barbuda                 9761115

# %%
wind_speed, wind_speed_table = get_coops_ssh(
    sos_name='wind_speed',
    units=cf_units.Unit('m/s'),
    bbox=bbox,
)

wind_speed_table
# Out:
#                                         depth      lat      lon  \
# station_name
# Navy Fuel Depot, FL                      None  30.4000 -81.6267
# Mayport (Bar Pilots Dock), FL            None  30.3982 -81.4279
# Blount Island Command, FL                None  30.3926 -81.5225
# I-295 Bridge, St Johns River, FL         None  30.1917 -81.6917
# Trident Pier, Port Canaveral, FL         None  28.4158 -80.5931
# Lake Worth Pier, Atlantic Ocean, FL      None  26.6128 -80.0342
# Virginia Key, Biscayne Bay, FL           None  25.7314 -80.1618
# Vaca Key, Florida Bay, FL                None  24.7110 -81.1065
# Key West, FL                             None  24.5557 -81.8079
# Naples, Gulf of Mexico, FL               None  26.1317 -81.8075
# Fort Myers, Caloosahatchee River, FL     None  26.6477 -81.8712
# Middle Tampa Bay, FL                     None  27.6618 -82.5995
# St Petersburg, Tampa Bay, FL             None  27.7606 -82.6269
# Old Port Tampa, FL                       None  27.8578 -82.5528
# East Bay Causeway, FL                    None  27.9289 -82.4258
# TPA Cruise Terminal 2, FL                None  27.9333 -82.4333
# Clearwater Beach, FL                     None  27.9783 -82.8317
# Cedar Key, FL                            None  29.1336 -83.0309
# Apalachicola, FL                         None  29.7267 -84.9817
# Panama City, FL                          None  30.1523 -85.6669
# Panama City Beach, FL                    None  30.2133 -85.8783
# Christiansted Harbor, St Croix, VI       None  17.7500 -64.7050
# Lime Tree Bay. St. Croix, VI             None  17.6947 -64.7538
# Charlotte Amalie, VI                     None  18.3358 -64.9200
# Isabel Segunda, Vieques Island, PR       None  18.1525 -65.4438
# Fajardo, PR                              None  18.3352 -65.6311
# Yabucoa Harbor, PR                       None  18.0551 -65.8330
# San Juan, La Puntilla, San Juan Bay, PR  None  18.4592 -66.1164
# Arecibo, PR                              None  18.4806 -66.7025
# Magueyes Island, PR                      None  17.9700 -67.0464
# Mayaguez, PR                             None  18.2176 -67.1588
# Barbuda, Antigua and Barbuda             None  17.5908 -61.8206
#
#                                                                              sensor  \
# station_name
# Navy Fuel Depot, FL                      urn:ioos:sensor:NOAA.NOS.CO-OPS:8720215:C1
# Mayport (Bar Pilots Dock), FL            urn:ioos:sensor:NOAA.NOS.CO-OPS:8720218:C1
# Blount Island Command, FL                urn:ioos:sensor:NOAA.NOS.CO-OPS:8720233:C1
# I-295 Bridge, St Johns River, FL         urn:ioos:sensor:NOAA.NOS.CO-OPS:8720357:C1
# Trident Pier, Port Canaveral, FL         urn:ioos:sensor:NOAA.NOS.CO-OPS:8721604:C1
# Lake Worth Pier, Atlantic Ocean, FL      urn:ioos:sensor:NOAA.NOS.CO-OPS:8722670:C1
# Virginia Key, Biscayne Bay, FL           urn:ioos:sensor:NOAA.NOS.CO-OPS:8723214:C1
# Vaca Key, Florida Bay, FL                urn:ioos:sensor:NOAA.NOS.CO-OPS:8723970:C1
# Key West, FL                             urn:ioos:sensor:NOAA.NOS.CO-OPS:8724580:C1
# Naples, Gulf of Mexico, FL               urn:ioos:sensor:NOAA.NOS.CO-OPS:8725110:C1
# Fort Myers, Caloosahatchee River, FL     urn:ioos:sensor:NOAA.NOS.CO-OPS:8725520:C1
# Middle Tampa Bay, FL                     urn:ioos:sensor:NOAA.NOS.CO-OPS:8726412:C1
# St Petersburg, Tampa Bay, FL             urn:ioos:sensor:NOAA.NOS.CO-OPS:8726520:C1
# Old Port Tampa, FL                       urn:ioos:sensor:NOAA.NOS.CO-OPS:8726607:C1
# East Bay Causeway, FL                    urn:ioos:sensor:NOAA.NOS.CO-OPS:8726679:C1
# TPA Cruise Terminal 2, FL                urn:ioos:sensor:NOAA.NOS.CO-OPS:8726694:C1
# Clearwater Beach, FL                     urn:ioos:sensor:NOAA.NOS.CO-OPS:8726724:C1
# Cedar Key, FL                            urn:ioos:sensor:NOAA.NOS.CO-OPS:8727520:C1
# Apalachicola, FL                         urn:ioos:sensor:NOAA.NOS.CO-OPS:8728690:C1
# Panama City, FL                          urn:ioos:sensor:NOAA.NOS.CO-OPS:8729108:C1
# Panama City Beach, FL                    urn:ioos:sensor:NOAA.NOS.CO-OPS:8729210:C1
# Christiansted Harbor, St Croix, VI       urn:ioos:sensor:NOAA.NOS.CO-OPS:9751364:C1
# Lime Tree Bay. St. Croix, VI             urn:ioos:sensor:NOAA.NOS.CO-OPS:9751401:C1
# Charlotte Amalie, VI                     urn:ioos:sensor:NOAA.NOS.CO-OPS:9751639:C1
# Isabel Segunda, Vieques Island, PR       urn:ioos:sensor:NOAA.NOS.CO-OPS:9752619:C1
# Fajardo, PR                              urn:ioos:sensor:NOAA.NOS.CO-OPS:9753216:C1
# Yabucoa Harbor, PR                       urn:ioos:sensor:NOAA.NOS.CO-OPS:9754228:C1
# San Juan, La Puntilla, San Juan Bay, PR  urn:ioos:sensor:NOAA.NOS.CO-OPS:9755371:C1
# Arecibo, PR                              urn:ioos:sensor:NOAA.NOS.CO-OPS:9757809:C1
# Magueyes Island, PR                      urn:ioos:sensor:NOAA.NOS.CO-OPS:9759110:C1
# Mayaguez, PR                             urn:ioos:sensor:NOAA.NOS.CO-OPS:9759394:C1
# Barbuda, Antigua and Barbuda             urn:ioos:sensor:NOAA.NOS.CO-OPS:9761115:C1
#
#                                         station_code
# station_name
# Navy Fuel Depot, FL                          8720215
# Mayport (Bar Pilots Dock), FL                8720218
# Blount Island Command, FL                    8720233
# I-295 Bridge, St Johns River, FL             8720357
# Trident Pier, Port Canaveral, FL             8721604
# Lake Worth Pier, Atlantic Ocean, FL          8722670
# Virginia Key, Biscayne Bay, FL               8723214
# Vaca Key, Florida Bay, FL                    8723970
# Key West, FL                                 8724580
# Naples, Gulf of Mexico, FL                   8725110
# Fort Myers, Caloosahatchee River, FL         8725520
# Middle Tampa Bay, FL                         8726412
# St Petersburg, Tampa Bay, FL                 8726520
# Old Port Tampa, FL                           8726607
# East Bay Causeway, FL                        8726679
# TPA Cruise Terminal 2, FL                    8726694
# Clearwater Beach, FL                         8726724
# Cedar Key, FL                                8727520
# Apalachicola, FL                             8728690
# Panama City, FL                              8729108
# Panama City Beach, FL                        8729210
# Christiansted Harbor, St Croix, VI           9751364
# Lime Tree Bay. St. Croix, VI                 9751401
# Charlotte Amalie, VI                         9751639
# Isabel Segunda, Vieques Island, PR           9752619
# Fajardo, PR                                  9753216
# Yabucoa Harbor, PR                           9754228
# San Juan, La Puntilla, San Juan Bay, PR      9755371
# Arecibo, PR                                  9757809
# Magueyes Island, PR                          9759110
# Mayaguez, PR                                 9759394
# Barbuda, Antigua and Barbuda                 9761115

# %%
common = set(ssh_table['station_code']).intersection(wind_speed_table['station_code'])

# %%
ssh_obs, win_obs = [], []
for station in common:
    ssh_obs.extend([obs for obs in ssh if obs._metadata['station_code'] == station])
    win_obs.extend([obs for obs in wind_speed if obs._metadata['station_code'] == station])

# %%
index = pd.date_range(start=start_time.replace(tzinfo=None),
                      end=end_time.replace(tzinfo=None),
                      freq='15min')

# Re-index and rename series.
ssh_observations = []
for series in ssh_obs:
    _metadata = series._metadata
    obs = series.reindex(index=index, limit=1, method='nearest')
    obs._metadata = _metadata
    obs.name = _metadata['station_name']
    ssh_observations.append(obs)

winds_observations = []
for series in win_obs:
    _metadata = series._metadata
    obs = series.reindex(index=index, limit=1, method='nearest')
    obs._metadata = _metadata
    obs.name = _metadata['station_name']
    winds_observations.append(obs)

# %% [markdown]
# For our interactive map we will use `bokeh` HTML plots instead of the usual raster `matplotlib` ones to enhance the user experience when exploring the graphs.

# %%
from bokeh.resources import CDN
from bokeh.plotting import figure
from bokeh.embed import file_html
from bokeh.models import Range1d, LinearAxis

from folium import IFrame

# Plot defaults.
tools = "pan,box_zoom,reset"
width, height = 750, 250


def make_plot(ssh, wind):
    p = figure(toolbar_location="above",
               x_axis_type="datetime",
               width=width,
               height=height,
               tools=tools,
               title=ssh.name)
    l0 = p.line(
        x=wind.index,
        y=wind.values,
        line_width=5,
        line_cap='round',
        line_join='round',
        legend='wind speed (m/s)',
        color='#9900cc',
        alpha=0.5,
    )
    p.extra_y_ranges = {}
    p.extra_y_ranges['y2'] = Range1d(
        start=0,
        end=3
    )
    p.add_layout(
        LinearAxis(y_range_name='y2', axis_label='wind speed (m/s)'),
        'right'
    )
    l1 = p.line(
        x=ssh.index,
        y=ssh.values,
        line_width=5,
        line_cap='round',
        line_join='round',
        legend='ssh (m)',
        color='#0000ff',
        alpha=0.5,
        y_range_name='y2',
    )
    p.legend.location = 'top_left'
    return p


def make_marker(p, location, fname):
    html = file_html(p, CDN, fname)
    iframe = IFrame(html, width=width+45, height=height+80)

    popup = folium.Popup(iframe, max_width=2650)
    icon = folium.Icon(color='green', icon='stats')
    marker = folium.Marker(location=location,
                           popup=popup,
                           icon=icon)
    return marker

# %% [markdown]
# In the cell below we use `geopandas` to load the latest prediction shapefile downloaded from NHC as of Sun, 10 Sep 2017 22:16:09 UTC

# %%
import os
import geopandas

pgn = geopandas.read_file(
    os.path.join('al112017_5day_latest', 'al112017-047_5day_pgn.shp')
)
latest = pgn['geometry'].values[0].__geo_interface__

gdf = geopandas.read_file(
    os.path.join('al112017_5day_latest', 'al112017-047_5day_pts.shp')
)

# %% [markdown]
# We will also use all the past predictions in the map.

# %%
from glob import glob

paths = []
for fname in sorted(glob(os.path.join('al112017_5day_latest', 'al112017-0*_5day_pgn.shp'))):
    pgn = geopandas.read_file(fname)
    paths.append(pgn['geometry'].values[0])

paths = [path.__geo_interface__ for path in paths]

points = []
for fname in sorted(glob(os.path.join('al112017_5day_latest', 'al112017-0*_5day_pts.shp'))):
    pts = geopandas.read_file(fname)
    points.append(pts.iloc[0])  # Only the first "obsevartion."

# %% [markdown]
# Before we start the map let's create a color code for the point track.

# %%
colors = {
    'Tropical Storm': 'yellow',
    'Hurricane': 'red',
    'Major Hurricane': 'crimson',
    'Subtropical Depression': 'darkorange',
    'Tropical Depression': 'orange'
}

# %% [markdown]
# Here is the final result. Explore the map by clicking on the map features plotted.

# %%
import folium
from folium.plugins import Fullscreen, MarkerCluster, MeasureControl

lon = (bbox[0] + bbox[2]) / 2.0
lat = (bbox[1] + bbox[3]) / 2.0

m = folium.Map(location=[lat, lon], tiles='OpenStreetMap', zoom_start=4)

Fullscreen(position='topright', force_separate_button=True).add_to(m)

marker_cluster0 = MarkerCluster(name='Sea Surface Height')
marker_cluster1 = MarkerCluster(name='Past predictions')
marker_cluster0.add_to(m)
marker_cluster1.add_to(m)


url = 'http://oos.soest.hawaii.edu/thredds/wms/hioos/satellite/dhw_5km'
w0 = folium.WmsTileLayer(url,
    name='sea_surface_temperature',
    fmt='image/png',
    layers='CRW_SST',
    attr='PacIOOS TDS',
    overlay=True,
    transparent=True)

w0.add_to(m)

url = 'http://hfrnet.ucsd.edu/thredds/wms/HFRNet/USEGC/6km/hourly/RTV'
w1 = folium.WmsTileLayer(url,
    name='HF Radar',
    fmt='image/png',
    layers='surface_sea_water_velocity',
    attr='HFRNet',
    overlay=True,
    transparent=True)

w1.add_to(m)

# %%
def style_function(feature):
    return {
        'fillOpacity': 0,
        'color': 'black',
        'stroke': 1,
        'weight': 0.5,
        'opacity': 0.2,
    }

# Latest prediction.
for k, row in gdf.iterrows():
    date = row['FLDATELBL']
    hclass = row['TCDVLP']
    location = row['LAT'], row['LON']
    popup = '{}<br>{}'.format(date, hclass)
    folium.CircleMarker(
        location=location,
        radius=10,
        fill=True,
        color=colors[hclass],
        popup=popup,
    ).add_to(m)

folium.GeoJson(
    data=latest,
    name='Cone prediction as of Sun, 10 Sep 2017 22:16:09 UTC'
).add_to(m)

# Past predictions.
for path in paths:
    folium.GeoJson(
        data=path,
        style_function=style_function
    ).add_to(marker_cluster1)

# Points along the track.
for point in points[::2]:
    date = point['FLDATELBL']
    hclass = point['TCDVLP']
    location = point['LAT'], point['LON']
    popup = '{}<br>{}'.format(date, hclass)
    folium.CircleMarker(
        location=location,
        radius=5,
        fill=True,
        color=colors[hclass],
        popup=popup,
    ).add_to(m)


# Observed sea surface height.
for ssh, wind in zip(ssh_observations, winds_observations):
    fname = ssh._metadata['station_code']
    location = ssh._metadata['lat'], ssh._metadata['lon']
    p = make_plot(ssh, wind)
    marker = make_marker(p, location=location, fname=fname)
    marker.add_to(marker_cluster0)

folium.LayerControl().add_to(m)

m.save('index.html')

# %% [markdown]
# Slim version that we can display on the notebook.

# %%
m = folium.Map(location=[lat, lon], tiles='OpenStreetMap', zoom_start=4)

Fullscreen(position='topright', force_separate_button=True).add_to(m)

marker_cluster0 = MarkerCluster(name='Observations')
marker_cluster0.add_to(m)

w0.add_to(m)
w1.add_to(m)

for k, row in gdf.iterrows():
    date = row['FLDATELBL']
    hclass = row['TCDVLP']
    location = row['LAT'], row['LON']
    popup = '{}<br>{}'.format(date, hclass)
    folium.CircleMarker(
        location=location,
        radius=10,
        fill=True,
        color=colors[hclass],
        popup=popup,
    ).add_to(m)

folium.GeoJson(
    data=latest,
    name='Cone prediction as of Sun, 10 Sep 2017 22:16:09 UTC'
).add_to(m)

# Observed sea surface height.
for ssh, wind in zip(ssh_observations, winds_observations):
    fname = ssh._metadata['station_code']
    location = ssh._metadata['lat'], ssh._metadata['lon']
    p = make_plot(ssh, wind)
    marker = make_marker(p, location=location, fname=fname)
    marker.add_to(marker_cluster0)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
